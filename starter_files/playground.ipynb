# %% [markdown]
# # How the function works

# %%
from template import (get_data, opioid_updates)

# %%
data = get_data()

# %%
new_updates = opioid_updates(data)

# %%
new_updates
# Out:
#             state                                     spending_plans
# 19      louisiana  participating state with state-subdivision agr...
# 28       nebraska  participating state with statutory trust proce...
# 39   pennsylvania  participating state with statutory trust and a...
# 43      tennessee  participating state with statutory trust and s...
# 49  west virginia  non-participating state* with state-subdivisio...

# %%
for update in new_updates['spending_plans']:
    print(update)
    print()
# Out:
# participating state with state-subdivision agreement that alters the default allocation. louisiana is participating in the $26 billion national settlement offer made by johnson & johnson and "big three" distributors mckesson, amerisourcebergen, and cardinal health. the louisiana state-local government opioid litigation memorandum of understanding (mou) describes how the state plans to allocate and spend its opioid settlement dollars. this state-subdivision agreement alters the "15%-15%-70%" default allocation framework put forth by the national settlement agreement documents to instead place all funds into the "opioid abatement fund" "for the benefit of the parishes and municipalities of the state," with these funds received "on behalf of the local governments" then further divvied up: 20% "to the benefit of sheriffs" and 80% "to the benefit of the other local governments." note: louisiana's ag and political subdivisions have already reached agreements to settle opioid-related claims
# ...

# %% [markdown]
# ----------

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
from datetime import datetime
from selenium import webdriver

# %% [markdown]
# # Creating header variable so websites won't detect scrapper

# %%
headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

# %%
url = 'https://www.opioidsettlementtracker.com/settlementspending'
r = requests.get(url, headers=headers)
soup = bs(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- This is Squarespace. -->
#   <!-- lanternfish-hexaflexagon-r376 -->
#   <base href=""/>
#   <meta charset="utf-8">
#    <title>
#     SETTLEMENT SPENDING — Opioid Settlement Tracker
#    </title>
#    <link href="https://images.squarespace-cdn.com/content/v1/5dba07107950bb1c1d409a4e/1572821963202-8MSGGG1NOZ2OIEWR9QVZ/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="https://www.opioidsettlementtracker.com/settlementspending" rel="canonical"/>
#    <meta content="Opioid Settlement Tracker" property="og:site_name">
#     <meta content="SETTLEMENT SPENDING — Opioid Settlement Tracker" property="og:title"/>
# ...

# %%
soup.find_all('script')
# Out:
# [<script src="//use.typekit.net/ik/7MMryoEOhHV_bMjTclRx4E9DiTlt-jNn5SIoOCOeWIwfe7CBfFHN4UJLFRbh52jhWDmqjcI3FDI3FDquwe4KwAwUZ2b35AIXZsnOMkG0jAFu-WsoShFGZAsude80ZkoRdhXCHKoyjamTiY8Djhy8ZYmC-Ao1Oco8if37OcBDOcu8OfG0deB0iemkdcZTSh6l-emtjAZCZWyyZhN0OWJDFDj0SaBujW48Sagyjh90jhNlOfG0SaBujW48SagyjhmDjhy8ZYmC-Ao1OcFzdPUyjamTiY8Djhy8ZYmC-Ao1OcFzdPUyjamTiY8Djhy8ZYmC-Ao1Oco8ifUySkolZPUCjAoXZW40Zc8D-fuGZWyyZcU8peB1dhtlSRwaFKoDSWmyScmDSeBRZPoRdhXCdeNRjAUGdaFXOeN3-ANTZYF8iYsCZAu8d1sXScBR-hmkOcFzdPUDSWmyScmDSeBRZWFR-emqiAUTdcS0jhNlOYiaikoyjamTiY8Djhy8ZYmC-Ao1OcFzdPUaiaS0jAFu-WsoShFGZAsude80Zko0ZWbCiaiaOcBDOcu8OYiaikoCjAoXZW40Zc8D-fuGZWyyZcU8peB1dhtlSRwaFKoDSWmyScmDSeBRZPoRdhXCiaiaOcN3-ANTZYF8iYsCZAu8d1sXScBR-hmkOcFzdPUaiaS0SaBujW48SagyjhmDjhy8ZYmC-Ao1OcFzdPJwSY4zpe8ljPu0daZyJy4yZeNKZPu1jW4ydAN0Zfu3ScvKfAZuiYmkjPu3ifG4fHvgIMMjgfMfH6qJK3IbMg6YJMJ7fbK3MsMMeMt6MKG4fJ3gIMMjIPMfH6qJvDbbMs6IJMJ7fbR3FgMgeMS6MKG4fVJXIMIj2KMfH6qJvQbbMs6sJMJ7fbKImsMfeMb6MKG4fJBmIMJjgkMfH6qJym9bMy65JMJ7fbKfmsMfegI6MTMgU_07N39.js"
# ...

# %%
soup.iframe['src']
# Out:
# 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSE0bsn0p8so7jAYi2whjJLt2MyZ_MljJPVgIcK3GutuRHxohzDwmFR4xx_iEPrRyOL0MigxTdfKsuP/pubhtml? widget=false& headers=false&chrome=false '

# %%
t = soup.find_all(class_='docs-gm')

# %%
print(t)
# Out:
# []

# %%
browser = webdriver.Chrome(executable_path='/Users/maazkhan/Desktop/shan_work/chrome_driver/chromedriver')

browser.get("https://www.python.org/")

nav = browser.find_element_by_id("mainnav")

print(nav.text)
# Out:
# <ipython-input-6-d18094fb8939>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path='/Users/maazkhan/Desktop/shan_work/chrome_driver/chromedriver')
# About
# Downloads
# Documentation
#
# Community
# Success Stories
# News
# Events
# <ipython-input-6-d18094fb8939>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nav = browser.find_element_by_id("mainnav")

# %%
r = requests.get('https://pt.wikipedia.org/wiki/Lista_de_bairros_de_Manaus')

soup = bs(r.content, 'html.parser')

# %%
soup.find(class_= 'icon-documentation')
# Out:
# <span aria-hidden="true" class="icon-documentation"></span>
